# %% [markdown]
# #  Применимость методов анализа
#
# Автор: Никоноров Е.Н.
# Дата: 21.11.2022
# Курс: Аналитик данных (Data scientist) 2022
# Кейс: №3 «Прогнозирование размеров сварного шва при электронно-лучевой сварке тонкостенных конструкций аэрокосмического назначения»
#
# Искомые параметры:
# 1.Width
# 2.Depth
#
#
# Описание файла:
# 1. Загружаем данные из initail, merged, generated
# 2. Формируем X, y
# 3. Разделяем на обучающую и тестовую выборки
# 4. Линейная регрессия
# 5. Деревья
# 6. Сети
# 8. Выбор целевого метода

# %%
#импорт библиотек

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from sklearn import preprocessing
from sklearn.multioutput import MultiOutputRegressor

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import recall_score


from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error



from sklearn.preprocessing import scale
from sklearn import set_config

# %%
#загрузка данных
df_merged = pd.read_excel("../Data/ds_merged.xlsx ")
df_merged = df_merged.drop(['Unnamed: 0'], axis =1)

df_initial = pd.read_excel("../Data/ds_initial.xlsx ")
df_initial = df_initial.drop(['Unnamed: 0'], axis =1)

df_generated = pd.read_excel("../Data/ds_generated.xlsx ")
df_generated = df_generated.drop(['Unnamed: 0'], axis =1)

# %%
#менять датасет тут
df = df_merged

X=df.iloc[:,:4].to_numpy()
y=df.iloc[:,4:].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9)

# %%
def plot_result(y_train,y_train_pred, y_test, y_pred):
    fig,axs = plt.subplots(figsize=(16,4), ncols=3)
    axs[0].scatter(y_train, y_train_pred)
    axs[0].set_title('train data')

    axs[1].scatter(y_pred, y_test, label="test data")
    axs[1].set_title('test data')
    err=y_pred - y_test
    axs[2].scatter(err[:,0], err[:,1], label="error")
    axs[2].set_title('error (test)')

    print('mse', mean_squared_error(y_test,y_pred))
    print('mae', mean_absolute_error(y_test,y_pred))
    print('Coef of determination', r2_score(y_test,y_pred))
    #reg.score(X_test, y_test)

    #((y_test-y_pred) ** 2).mean()

# %% [markdown]
# #     Линейная регрессия

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X_train, y_train)
y_train_pred = reg.predict(X_train)
y_pred = reg.predict(X_test)

plot_result(y_train,y_train_pred, y_test, y_pred)


cross_val_score(reg, X, y)
# Out:
# mse 0.01027762533807459
# mae 0.08725506266162382
# Coef of determination 0.30385160299464553
# array([ 0.51380221,  0.41637381,  0.64397514, -1.39734974, -2.20889115])

# %% [markdown]
# # Support Vector Regression

# %%
#from sklearn.svm import SVR

#svr_rbf = SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1)
#svr_lin = SVR(kernel="linear", C=100, gamma="auto")
#svr_poly = SVR(kernel="poly", C=100, gamma="auto", degree=3, epsilon=0.1, coef0=1)

#y_train_0 = y_train[:,0]
#y_train_1 = y_train[:,1]

#y_test_0 = y_test[:,0]
#y_test_1 = y_test[:,1]

#reg = svr_rbf.fit(X_train, y_train_0)
#y_pred = reg.predict(X_test)

#plot_result(y_train_0, y_test_0, y_pred)

# %%
from sklearn.svm import SVR

svr_rbf = SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1)
svr_lin = SVR(kernel="linear", C=100, gamma="auto")
svr_poly = SVR(kernel="poly", C=100, gamma="auto", degree=3, epsilon=0.1, coef0=1)

print('rbf')
multiSvr = MultiOutputRegressor(svr_rbf)
reg = multiSvr.fit(X_train, y_train)
y_train_pred = reg.predict(X_train)
y_pred = reg.predict(X_test)
plot_result(y_train,y_train_pred, y_test, y_pred)
cross_val_score(reg, X, y, cv=10)

#работает долго и менее точно
#print('lin')
#multiSvr = MultiOutputRegressor(svr_lin)
#reg = multiSvr.fit(X_train, y_train)
#y_train_pred = reg.predict(X_train)
#y_pred = reg.predict(X_test)
#plot_result(y_train,y_train_pred, y_test, y_pred)

#виснет на сгенерированном датасете
#print('poly')
#multiSvr = MultiOutputRegressor(svr_poly)
#reg = multiSvr.fit(X_train, y_train)
#y_train_pred = reg.predict(X_train)
#y_pred = reg.predict(X_test)
#plot_result(y_train,y_train_pred, y_test, y_pred)
# Out:
# rbf
# mse 0.007483272427262494
# mae 0.07102821399521972
# Coef of determination 0.5684056845276689
# array([-16.02703067,  -0.31946505,  -0.82097004,   0.84167401,
#          0.80271445,   0.88830163,  -0.68741908,  -2.36073492,
#         -1.66851847, -10.29348044])

# %% [markdown]
# # RandomForest

# %%
max_depth = 20

print('rf')
multi = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, max_depth=max_depth, random_state=0))
reg = multi.fit(X_train, y_train)
y_train_pred = reg.predict(X_train)
y_pred = reg.predict(X_test)
plot_result(y_train,y_train_pred, y_test, y_pred)

cross_val_score(reg, X, y, cv=10, scoring = 'r2')
# Out:
# rf
# mse 0.006076561243632599
# mae 0.05654385582557299
# Coef of determination 0.6536616262651984
# array([-41.86805153, -17.02938621,  -0.90823512,   0.80485439,
#          0.86370262,   0.84335062,  -3.30263488,  -0.95639014,
#         -1.13333612,  -4.07206584])

# %% [markdown]
# # Дерево решений

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor


print('Dtree')
multi = MultiOutputRegressor(DecisionTreeRegressor(random_state=42, max_depth=max_depth))
reg = multi.fit(X_train, y_train)
y_train_pred = reg.predict(X_train)
y_pred = reg.predict(X_test)
plot_result(y_train,y_train_pred, y_test, y_pred)

cross_val_score(reg, X, y, cv=10)
# Out:
# Dtree
# mse 0.007503774296624707
# mae 0.05800647784042394
# Coef of determination 0.8782603697104676
# array([0.91017421, 0.85833742, 0.80909226, 0.80411771, 0.87392391,
#        0.86627262, 0.89401973, 0.82364866, 0.80910675, 0.86992933])

# %% [markdown]
# # Multi-layer Perceptron regressor

# %%
from sklearn.neural_network import MLPRegressor


print('Multi-layer Perceptron')
mlp = MLPRegressor(random_state=13, max_iter=1500, batch_size=50  )
reg = mlp.fit(X_train, y_train)
y_train_pred = reg.predict(X_train)
y_pred = reg.predict(X_test)
plot_result(y_train,y_train_pred, y_test, y_pred)

mlp.hidden_layer_sizes
cross_val_score(reg, X, y, cv=10)
# Out:
# Multi-layer Perceptron
# mse 0.010475382962602817
# mae 0.07531452776711618
# Coef of determination 0.8034046822554345
# array([0.75365249, 0.73912677, 0.69873948, 0.73842131, 0.76255433,
#        0.79490976, 0.82186914, 0.65876759, 0.67396486, 0.81753858])

# %% [markdown]
# # Нейронная сеть

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model

# %%
print('NN')

NN_m = tf.keras.Sequential()
NN_m.add(tf.keras.layers.Dense(units= 100, input_shape=(X_train.shape[1],)))
NN_m.add(tf.keras.layers.Dense(units = 100, activation = "relu"))
NN_m.add(tf.keras.layers.Dense(units = 2, activation = "linear"))

NN_m.compile(optimizer = 'Adam', loss = 'mse',
             metrics=[tf.keras.metrics.RootMeanSquaredError()])

NN_m.fit(X_train, y_train, epochs=100)

y_train_pred = NN_m.predict(X_train)
y_pred = NN_m.predict(X_test)


plot_result(y_train,y_train_pred, y_test, y_pred)
# Out:
# NN
# Epoch 1/100
# 31/31 [==============================] - 1s 5ms/step - loss: 9.5382 - root_mean_squared_error: 3.0884
# Epoch 2/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4271 - root_mean_squared_error: 0.6535
# Epoch 3/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2658 - root_mean_squared_error: 0.5155
# Epoch 4/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2319 - root_mean_squared_error: 0.4815
# Epoch 5/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1828 - root_mean_squared_error: 0.4275
# Epoch 6/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1435 - root_mean_squared_error: 0.3789
# Epoch 7/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1414 - root_mean_squared_error: 0.3760
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1010 - root_mean_squared_error: 0.3179
# Epoch 9/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0877 - root_mean_squared_error: 0.2962
# Epoch 10/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0648 - root_mean_squared_error: 0.2546
# Epoch 11/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319
# Epoch 12/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0616 - root_mean_squared_error: 0.2481
# Epoch 13/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0426 - root_mean_squared_error: 0.2064
# Epoch 14/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0367 - root_mean_squared_error: 0.1915
# Epoch 15/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0390 - root_mean_squared_error: 0.1975
# Epoch 16/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0412 - root_mean_squared_error: 0.2029
# Epoch 17/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772
# Epoch 18/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0479 - root_mean_squared_error: 0.2188
# Epoch 19/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429
# Epoch 20/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685
# Epoch 21/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0302 - root_mean_squared_error: 0.1738
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0462 - root_mean_squared_error: 0.2151
# Epoch 24/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0725 - root_mean_squared_error: 0.2693
# Epoch 25/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0417 - root_mean_squared_error: 0.2043
# Epoch 26/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0461 - root_mean_squared_error: 0.2148
# Epoch 27/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512
# Epoch 28/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561
# Epoch 29/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0403 - root_mean_squared_error: 0.2007
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0390 - root_mean_squared_error: 0.1976
# Epoch 31/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531
# Epoch 32/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0533 - root_mean_squared_error: 0.2308
# Epoch 33/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0555 - root_mean_squared_error: 0.2356
# Epoch 34/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927
# Epoch 35/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0997 - root_mean_squared_error: 0.3157
# Epoch 36/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0430 - root_mean_squared_error: 0.2073
# Epoch 37/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0434 - root_mean_squared_error: 0.2083
# Epoch 38/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595
# Epoch 40/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0217 - root_mean_squared_error: 0.1472
# Epoch 41/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0607 - root_mean_squared_error: 0.2465
# Epoch 42/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0570 - root_mean_squared_error: 0.2387
# Epoch 43/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695
# Epoch 44/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0391 - root_mean_squared_error: 0.1978
# Epoch 45/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0395 - root_mean_squared_error: 0.1987
# Epoch 46/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0396 - root_mean_squared_error: 0.1990
# Epoch 47/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 48/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0651 - root_mean_squared_error: 0.2552
# Epoch 49/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1281 - root_mean_squared_error: 0.3579
# Epoch 50/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0800 - root_mean_squared_error: 0.2828
# Epoch 51/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1250 - root_mean_squared_error: 0.3536
# Epoch 52/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0777 - root_mean_squared_error: 0.2788
# Epoch 54/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0554 - root_mean_squared_error: 0.2355
# Epoch 55/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1587
# Epoch 56/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0417 - root_mean_squared_error: 0.2043
# Epoch 58/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0476 - root_mean_squared_error: 0.2181
# Epoch 59/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0471 - root_mean_squared_error: 0.2171
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0597 - root_mean_squared_error: 0.2443
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1918 - root_mean_squared_error: 0.4379
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0710 - root_mean_squared_error: 0.2665
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0505 - root_mean_squared_error: 0.2247
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0545 - root_mean_squared_error: 0.2334
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0439 - root_mean_squared_error: 0.2095
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571
# Epoch 67/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0353 - root_mean_squared_error: 0.1879
# Epoch 68/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0658 - root_mean_squared_error: 0.2566
# Epoch 70/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1940 - root_mean_squared_error: 0.4405
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0869 - root_mean_squared_error: 0.2949
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0827 - root_mean_squared_error: 0.2875
# Epoch 73/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1251 - root_mean_squared_error: 0.3536
# Epoch 74/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1102 - root_mean_squared_error: 0.3319
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0926 - root_mean_squared_error: 0.3043
# Epoch 76/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0598 - root_mean_squared_error: 0.2445
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1105 - root_mean_squared_error: 0.3325
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1232 - root_mean_squared_error: 0.3511
# Epoch 79/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2037 - root_mean_squared_error: 0.4514
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0536 - root_mean_squared_error: 0.2314
# Epoch 81/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0290 - root_mean_squared_error: 0.1703
# Epoch 82/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0621 - root_mean_squared_error: 0.2492
# Epoch 83/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0679 - root_mean_squared_error: 0.2606
# Epoch 84/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0309 - root_mean_squared_error: 0.1756
# Epoch 85/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0348 - root_mean_squared_error: 0.1864
# Epoch 86/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0934 - root_mean_squared_error: 0.3056
# Epoch 87/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.1771
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0684 - root_mean_squared_error: 0.2614
# Epoch 90/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0315 - root_mean_squared_error: 0.1774
# Epoch 91/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0485 - root_mean_squared_error: 0.2201
# Epoch 92/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0624 - root_mean_squared_error: 0.2498
# Epoch 93/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0934 - root_mean_squared_error: 0.3056
# Epoch 94/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2314 - root_mean_squared_error: 0.4811
# Epoch 95/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1801 - root_mean_squared_error: 0.4244
# Epoch 96/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0402 - root_mean_squared_error: 0.2006
# Epoch 97/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0302 - root_mean_squared_error: 0.1739
# Epoch 98/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0455 - root_mean_squared_error: 0.2133
# Epoch 99/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0406 - root_mean_squared_error: 0.2016
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0719 - root_mean_squared_error: 0.2682
# 31/31 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# mse 0.10724404053999981
# mae 0.280718910506478
# Coef of determination -0.3796642915392288

# %% [markdown]
# # Выводы:

# %%
#На начальных, генерированных и смешанных данных лучший результат показал RandomForest
